# %%
from seleniumbase import Driver

import time
from PIL import Image

# %%
driver = Driver(uc=True)

# %%
driver.open("https://www.marinetraffic.com/en/ais/home/centerx:132.2/centery:43.0/zoom:10")

# %%
# Click agree button
driver.click('button:contains("AGREE")')

# %%
driver.save_screenshot("0-open-website.png")
# Out:
# True

# %%
driver.close()

# %%
img = Image.open("0-open-website.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1280x753>
